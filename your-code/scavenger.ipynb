# %%
import requests
import pandas as pd
import json

# %%
repo='https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/forks'
response = requests.get(repo)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# [{'id': 278336683,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzgzMzY2ODM=',
#   'name': 'bcn-feb-2019',
#   'full_name': 'franbaldi/bcn-feb-2019',
#   'private': False,
#   'owner': {'login': 'franbaldi',
#    'id': 25199469,
#    'node_id': 'MDQ6VXNlcjI1MTk5NDY5',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/25199469?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/franbaldi',
#    'html_url': 'https://github.com/franbaldi',
#    'followers_url': 'https://api.github.com/users/franbaldi/followers',
#    'following_url': 'https://api.github.com/users/franbaldi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/franbaldi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/franbaldi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/franbaldi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/franbaldi/orgs',
# ...

# %%
response_df = pd.DataFrame(response.json())
response_df
# Out:
#           id                           node_id          name  \
# 0  278336683  MDEwOlJlcG9zaXRvcnkyNzgzMzY2ODM=  bcn-feb-2019
# 1  276718167  MDEwOlJlcG9zaXRvcnkyNzY3MTgxNjc=  bcn-feb-2019
#
#                     full_name  private  \
# 0      franbaldi/bcn-feb-2019    False
# 1  brunacarolino/bcn-feb-2019    False
#
#                                                owner  \
# 0  {'login': 'franbaldi', 'id': 25199469, 'node_i...
# 1  {'login': 'brunacarolino', 'id': 67610079, 'no...
#
#                                         html_url description  fork  \
# 0      https://github.com/franbaldi/bcn-feb-2019        None  True
# 1  https://github.com/brunacarolino/bcn-feb-2019        None  True
#
#                                                  url  ... forks_count  \
# 0  https://api.github.com/repos/franbaldi/bcn-feb...  ...           0
# 1  https://api.github.com/repos/brunacarolino/bcn...  ...           0
#
#   mirror_url archived disabled open_issues_count  \
# ...

# %%
response_df.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
response_df['language'].unique()
# Out:
# array([None, 'Jupyter Notebook'], dtype=object)

# %%
#-------Challenge 2-----------

url = 'https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/commits'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# [{'sha': '6a243303cfd846faac16417cad54cd40ab3f82c6',
#   'node_id': 'MDY6Q29tbWl0MjAzMTMyMjg2OjZhMjQzMzAzY2ZkODQ2ZmFhYzE2NDE3Y2FkNTRjZDQwYWIzZjgyYzY=',
#   'commit': {'author': {'name': 'Carlos Madriz',
#     'email': '45972288+carlosmd14@users.noreply.github.com',
#     'date': '2019-08-19T11:12:15Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2019-08-19T11:12:15Z'},
#    'message': 'Update README.md',
#    'tree': {'sha': '5696a145dbbeef9a0417d852b706178bbca30900',
#     'url': 'https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/git/trees/5696a145dbbeef9a0417d852b706178bbca30900'},
#    'url': 'https://api.github.com/repos/ta-data-lis/lab-mysql-first-queries/git/commits/6a243303cfd846faac16417cad54cd40ab3f82c6',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
# ...

# %%
commits = pd.json_normalize(resp.json())

# %%
commits
# Out:
#                                         sha  \
# 0  6a243303cfd846faac16417cad54cd40ab3f82c6
# 1  ee6d046595a26c76425df9fffdb6ed6737c7c06b
# 2  381994f755b6b95ffc4fe512f36e2640bd04034f
# 3  2e9b232b72bec7218cd77f171098a7391d89ba8c
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjAzMTMyMjg2OjZhMjQzMzAzY2ZkODQ2Zm...
# 1  MDY6Q29tbWl0MjAzMTMyMjg2OmVlNmQwNDY1OTVhMjZjNz...
# 2  MDY6Q29tbWl0MjAzMTMyMjg2OjM4MTk5NGY3NTViNmI5NW...
# 3  MDY6Q29tbWl0MjAzMTMyMjg2OjJlOWIyMzJiNzJiZWM3Mj...
#
#                                                  url  \
# 0  https://api.github.com/repos/ta-data-lis/lab-m...
# 1  https://api.github.com/repos/ta-data-lis/lab-m...
# 2  https://api.github.com/repos/ta-data-lis/lab-m...
# 3  https://api.github.com/repos/ta-data-lis/lab-m...
#
#                                             html_url  \
# 0  https://github.com/ta-data-lis/lab-mysql-first...
# 1  https://github.com/ta-data-lis/lab-mysql-first...
# ...

# %%
commits['commit.author.date']
#As we can see all the commits remote to august, therefore its obvious that no commit has been made in the last 2 weeks
# Out:
# 0    2019-08-19T11:12:15Z
# 1    2019-08-19T11:11:55Z
# 2    2019-08-19T11:10:23Z
# 3    2019-08-19T08:36:54Z
# Name: commit.author.date, dtype: object
